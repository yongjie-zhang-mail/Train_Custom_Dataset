# %% [markdown]
# # YOLOV8关键点检测预测-命令行-图像
#
# 同济子豪兄 2023-4-15

# %% [markdown]
# ## 关键点检测预测

# %%
# !yolo pose predict model=checkpoint/Triangle_215_yolov8x_p6_pretrain.pt source=images/triangle_4.jpg device=0

# !yolo pose predict model=checkpoint/last.pt source=images/triangle_4.jpg device=cpu
# Out:
# Ultralytics YOLOv8.0.145  Python-3.9.15 torch-1.13.1 CPU (12th Gen Intel Core(TM) i7-12700H)
# YOLOv8s-pose summary (fused): 187 layers, 11412750 parameters, 0 gradients, 29.4 GFLOPs
#
# image 1/1 C:\source\ai\zihao\Train_Custom_Dataset\lab5\images\triangle_4.jpg: 448x640 3 sjb_rects, 215.5ms
# Speed: 4.1ms preprocess, 215.5ms inference, 7.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\pose\predict

# %% [markdown]
# ## 预测结果保存在`runs`目录

# %%
# 保存 txt 预测结果
# !yolo pose predict model=checkpoint/Triangle_215_yolov8x_p6_pretrain.pt source=images/triangle_4.jpg device=0 save_txt save_crop

# !yolo pose predict model=checkpoint/best.pt source=images/triangle_4.jpg device=cpu save_txt save_crop
# Out:
# Ultralytics YOLOv8.0.145  Python-3.9.15 torch-1.13.1 CPU (12th Gen Intel Core(TM) i7-12700H)
# YOLOv8s-pose summary (fused): 187 layers, 11412750 parameters, 0 gradients, 29.4 GFLOPs
#
# image 1/1 C:\source\ai\zihao\Train_Custom_Dataset\lab5\images\triangle_4.jpg: 448x640 3 sjb_rects, 148.3ms
# Speed: 3.0ms preprocess, 148.3ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\pose\predict2
# 1 label saved to runs\pose\predict2\labels

# %%
# 保存 txt 预测结果
# !yolo pose predict model=checkpoint/Triangle_215_yolov8x_p6_pretrain.pt source=images/triangle_4.jpg device=0 save_conf

# !yolo pose predict model=checkpoint/best.pt source=images/triangle_4.jpg device=cpu save_conf
# Out:
# Ultralytics YOLOv8.0.145  Python-3.9.15 torch-1.13.1 CPU (12th Gen Intel Core(TM) i7-12700H)
# YOLOv8s-pose summary (fused): 187 layers, 11412750 parameters, 0 gradients, 29.4 GFLOPs
#
# image 1/1 C:\source\ai\zihao\Train_Custom_Dataset\lab5\images\triangle_4.jpg: 448x640 3 sjb_rects, 190.1ms
# Speed: 4.0ms preprocess, 190.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\pose\predict3
